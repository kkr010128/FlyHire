# %%
import re
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support.ui import WebDriverWait
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import Select
import csv, time
import pandas as pd

ID = "ohhunmi24@gmail.com"
PASSWORD = "As589788@@"


# 직군 : 개발
occupation_value = '518'

# 직무 : 개발 관련된 것들..
job_value_list = []

# 기술 스택
teck_stacks = []

# %%
# 옵션 객체 하나만!
options = Options()
prefs = {
    "profile.default_content_setting_values.notifications": 2,  # 알림 차단
    "profile.default_content_setting_values.geolocation": 2,    # 위치 권한 차단
    "profile.default_content_setting_values.media_stream_mic": 2,  # 마이크 차단
    "profile.default_content_setting_values.media_stream_camera": 2,  # 카메라 차단
}
options.add_experimental_option("prefs", prefs)

# GUI 없이 실행 예시 (필요하면 주석 해제)
options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36")
options.add_argument("--headless")

# ✅ 드라이버 실행
driver = webdriver.Chrome(
    service=Service(ChromeDriverManager().install()),
    options=options
)

wait = WebDriverWait(driver, 5)

driver.get('https://www.wanted.co.kr/discovery?job=518&subJob=1024&annual=-0#skill-hired')
print("원티드 홈페이지 접속 완료...")
# Out:
# 원티드 홈페이지 접속 완료...

# %%
try:
    login_button = wait.until(EC.element_to_be_clickable((
    By.CSS_SELECTOR,
    '#__next > main > div.LoginModal_LoginModal__ZK1sd > div.LoginModal_LoginModal_body__XT3H4 > button.Button_Button__root__MS62F.Button_Button__contained__ftxwc.Button_Button__containedPrimary__oQnx2.Button_Button__containedSizeLarge__f0aza.LoginModal_LoginModal_body_login__fO3og'
    )))
    login_button.click()
    print('로그인 버튼 클릭 성공')
except Exception as e:
    print("로그인 버튼을 찾지 못했습니다.")
    print(e)

try:
    login_to_email_button = wait.until(EC.element_to_be_clickable((
    By.CSS_SELECTOR,
    '#__next > main > section > div > div > div > div.css-1qafqms > form > div.css-1qsnvsb > button.css-vwpg9b'
    )))
    login_to_email_button.click()
    print('이메일로 로그인 버튼 클릭 성공')
except Exception as e:
    print("이메일로 로그인 버튼을 찾지 못했습니다...")
    print(e)

try:
    id_input = wait.until(EC.element_to_be_clickable((
        By.CSS_SELECTOR,
        '#email'
    )))
    # 텍스트 입력
    id_input.send_keys(ID)
    print("아이디 제출 성공")
except Exception as e:
    print("아이디 입력에 실패했습니다.")
    print(e)

try:
    password_input = wait.until(EC.element_to_be_clickable((
    By.CSS_SELECTOR,
    '#__next > main > section > div > div > div.css-1qjqoce > form > div:nth-child(1) > div.css-1dxhdfz > input'
    )))
    
    password_input.send_keys(PASSWORD)
    print("비밀번호 제출 완료")
except Exception as e:
    print("비밀번호 제출에 실패했습니다.")
    print(e)

try:
    submit_login_button = driver.find_element(By.CSS_SELECTOR,'#__next > main > section > div > div > div.css-1qjqoce > form > div:nth-child(1) > button')
    submit_login_button.click()
    print("로그인을 성공했습니다!")
except Exception as e:
    print("로그인에 실패했습니다...")
    print(e)
# Out:
# 로그인 버튼 클릭 성공
# 이메일로 로그인 버튼 클릭 성공
# 아이디 제출 성공
# 비밀번호 제출 완료
# 로그인을 성공했습니다!

# %%
#  직군 select
occupation_select_element = wait.until(EC.presence_of_element_located((
    By.CSS_SELECTOR,
    '#__next > main > section > article.FilterList_FilterList__0T9Zj > label:nth-child(1) > div > select'
)))

#  직무 select
job_select_element = wait.until(EC.presence_of_element_located((
    By.CSS_SELECTOR,
    '#__next > main > section > article.FilterList_FilterList__0T9Zj > label:nth-child(2) > div > select'
)))
#  경력 select
carrer_select_element = wait.until(EC.presence_of_element_located((
    By.CSS_SELECTOR,
    '#__next > main > section > article.FilterList_FilterList__0T9Zj > label:nth-child(3) > div > select'
)))
apply_button= wait.until(EC.presence_of_element_located((
    By.CSS_SELECTOR,
    '#__next > main > section > article.FilterList_FilterList__0T9Zj > button'
)))

# %%
occupation_select = Select(occupation_select_element)
occupation_select.select_by_value(occupation_value)

# %%
job_select = Select(job_select_element)
job_select_options = job_select.options

# %%
carret_select = Select(carrer_select_element)
#carret_select.select_by_index(1) # 경력 연수가 신입 없는 직무가 존재함 (예: CTO)

# %%
# 직무 옵션 리스트 저장하기
for option in job_select_options[1:]:
    job_value_list.append(option.text)

# %%
job_value_list
# Out:
# ['데이터 엔지니어',
#  '임베디드 개발자',
#  '자바 개발자',
#  '.NET 개발자',
#  '시스템,네트워크 관리자',
#  '프론트엔드 개발자',
#  '하드웨어 엔지니어',
#  'DevOps / 시스템 관리자',
#  'QA,테스트 엔지니어',
#  '안드로이드 개발자',
#  'iOS 개발자',
#  'CTO,Chief Technology Officer',
#  '서버 개발자',
#  '웹 개발자',
#  '프로덕트 매니저',
#  '개발 매니저',
#  'Node.js 개발자',
#  '영상,음성 엔지니어',
#  '파이썬 개발자',
#  'C,C++ 개발자',
#  '웹 퍼블리셔',
#  'BI 엔지니어',
#  '데이터 사이언티스트',
#  '빅데이터 엔지니어',
#  '기술지원',
#  '블록체인 플랫폼 엔지니어',
#  '머신러닝 엔지니어',
#  '소프트웨어 엔지니어',
#  '크로스플랫폼 앱 개발자',
#  'DBA']

# %%
 def run_job_search():
    for job_value in range(len(job_value_list)):        
        try:    
            job_select.select_by_visible_text(job_value_list[job_value])
            carret_select.select_by_index(1)
            time.sleep(1)
            apply_button.click()
            print(f"{job_value_list[job_value]}직무 선택!")
            time.sleep(1)
    
            
        except Exception as e:
            print(f"{job_value_list[job_value]}에서 오류 발생 :{e}")
            continue
run_job_search()
# Out:
# 데이터 엔지니어에서 오류 발생 :Message: Could not locate element with index 1; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
#
# 임베디드 개발자에서 오류 발생 :Message: Could not locate element with index 1; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
#
# 자바 개발자에서 오류 발생 :Message: Could not locate element with index 1; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
#
# .NET 개발자에서 오류 발생 :Message: Could not locate element with index 1; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
#
# 시스템,네트워크 관리자에서 오류 발생 :Message: Could not locate element with index 1; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
#
# 프론트엔드 개발자에서 오류 발생 :Message: Could not locate element with index 1; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
#
# 하드웨어 엔지니어에서 오류 발생 :Message: Could not locate element with index 1; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
#
# DevOps / 시스템 관리자에서 오류 발생 :Message: Could not locate element with index 1; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
#
# QA,테스트 엔지니어에서 오류 발생 :Message: Could not locate element with index 1; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
#
# 안드로이드 개발자에서 오류 발생 :Message: Could not locate element with index 1; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
#
# iOS 개발자에서 오류 발생 :Message: Could not locate element with index 1; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
#
# CTO,Chief Technology Officer에서 오류 발생 :Message: Could not locate element with index 1; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
#
# 서버 개발자에서 오류 발생 :Message: Could not locate element with index 1; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
#
# 웹 개발자에서 오류 발생 :Message: Could not locate element with index 1; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
#
# 프로덕트 매니저에서 오류 발생 :Message: Could not locate element with index 1; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
#
# 개발 매니저에서 오류 발생 :Message: Could not locate element with index 1; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
#
# Node.js 개발자에서 오류 발생 :Message: Could not locate element with index 1; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
#
# 영상,음성 엔지니어에서 오류 발생 :Message: Could not locate element with index 1; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
#
# 파이썬 개발자에서 오류 발생 :Message: Could not locate element with index 1; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
#
# C,C++ 개발자에서 오류 발생 :Message: Could not locate element with index 1; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
#
# 웹 퍼블리셔에서 오류 발생 :Message: Could not locate element with index 1; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
#
# BI 엔지니어에서 오류 발생 :Message: Could not locate element with index 1; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
#
# 데이터 사이언티스트직무 선택!
# 빅데이터 엔지니어에서 오류 발생 :Message: Could not locate element with index 1; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
#
# 기술지원에서 오류 발생 :Message: Could not locate element with index 1; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
#
# 블록체인 플랫폼 엔지니어에서 오류 발생 :Message: Could not locate element with index 1; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
#
# 머신러닝 엔지니어에서 오류 발생 :Message: Could not locate element with index 1; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
#
# 소프트웨어 엔지니어에서 오류 발생 :Message: Could not locate element with index 1; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
#
# 크로스플랫폼 앱 개발자에서 오류 발생 :Message: Could not locate element with index 1; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
#
# DBA에서 오류 발생 :Message: Could not locate element with index 1; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception

# %%
# 결과 저장할 리스트
result = []

time.sleep(2)

for job_value in range(len(job_value_list)):        
    try:    
        job_select.select_by_visible_text(job_value_list[job_value])
        carret_select.select_by_index(1)
        time.sleep(1)
        apply_button.click()
        print(f"{job_value_list[job_value]} 직무 선택!")
        time.sleep(1)
        
        tech_stacks_element = wait.until(EC.presence_of_element_located((
            By.CSS_SELECTOR,
            '#__next > main > section > article.SkillInfo_SkillInfo__YSa5v > div:nth-child(2) > div.BarList_BarList__GvAW3'
        )))
        
        tech_stacks_text = tech_stacks_element.text.strip()

        if tech_stacks_text:
            lines = tech_stacks_text.split('\n')
            extracted_stacks = [line for line in lines if not any(char.isdigit() for char in line) and '%' not in line]
        else:
            extracted_stacks = None

        print(extracted_stacks)

        # ✅ 기술스택이 없어도 직무명은 저장, 기술스택은 None
        result.append({
            '직무': job_value_list[job_value],
            '기술스택': ', '.join(extracted_stacks) if extracted_stacks else None
        })

    except Exception as e:
        print(f"{job_value_list[job_value]}에서 오류 발생 : {e}")
        # ✅ 오류가 나도 직무명만이라도 기록!
        result.append({
            '직무': job_value_list[job_value],
            '기술스택': None
        })
        continue  # 오류나도 무조건 실행

# ✅ pandas DataFrame 으로 CSV 저장
df = pd.DataFrame(result)
df.to_csv('job_tech_stacks.csv', index=False, encoding='utf-8-sig')
print("CSV 저장 완료!")
# Out:
# 데이터 엔지니어 직무 선택!
# ['Python', 'PostgreSQL', 'SQL', '데이터베이스', '데이터 분석', '사업 전략', '데이터 마트', 'GitHub', 'Git', '데이터웨어 하우징']
# 임베디드 개발자 직무 선택!
# 임베디드 개발자에서 오류 발생 : Message:
# Stacktrace:
# 0   chromedriver                        0x0000000105188ea4 cxxbridge1$str$ptr + 2722840
# 1   chromedriver                        0x0000000105180dac cxxbridge1$str$ptr + 2689824
# 2   chromedriver                        0x0000000104cd23ec cxxbridge1$string$len + 90648
# 3   chromedriver                        0x0000000104d19544 cxxbridge1$string$len + 381808
# 4   chromedriver                        0x0000000104d5a934 cxxbridge1$string$len + 649056
# 5   chromedriver                        0x0000000104d0d834 cxxbridge1$string$len + 333408
# 6   chromedriver                        0x000000010514bfc0 cxxbridge1$str$ptr + 2473268
# 7   chromedriver                        0x000000010514f22c cxxbridge1$str$ptr + 2486176
# 8   chromedriver                        0x000000010512da08 cxxbridge1$str$ptr + 2348924
# 9   chromedriver                        0x000000010514fae8 cxxbridge1$str$ptr + 2488412
# 10  chromedriver                        0x000000010511ea98 cxxbridge1$str$ptr + 2287628
# 11  chromedriver                        0x000000010516f9d8 cxxbridge1$str$ptr + 2619212
# 12  chromedriver                        0x000000010516fb64 cxxbridge1$str$ptr + 2619608
# 13  chromedriver                        0x00000001051809e8 cxxbridge1$str$ptr + 2688860
# 14  libsystem_pthread.dylib             0x000000018209ec0c _pthread_start + 136
# 15  libsystem_pthread.dylib             0x0000000182099b80 thread_start + 8
#
# 자바 개발자 직무 선택!
# ['Java', 'Git', 'JavaScript', 'Spring Boot', 'Oracle', 'Spring Framework', 'MySQL', 'CSS', 'HTML', 'SQL']
# .NET 개발자 직무 선택!
# ['C / C++', 'Java', 'FastAPI', 'Docker', 'AWS', 'Nginx', 'Spring Boot', 'MySQL', 'Python', 'PyTorch']
# 시스템,네트워크 관리자 직무 선택!
# ['AWS', 'Kubernetes', 'Linux', 'Python']
# 프론트엔드 개발자 직무 선택!
# ['JavaScript', 'Git', 'React', 'TypeScript', 'HTML', 'CSS', 'Next.js', 'GitHub', 'PHP', 'Laravel']
# 하드웨어 엔지니어 직무 선택!
# 하드웨어 엔지니어에서 오류 발생 : Message:
# Stacktrace:
# 0   chromedriver                        0x0000000105188ea4 cxxbridge1$str$ptr + 2722840
# 1   chromedriver                        0x0000000105180dac cxxbridge1$str$ptr + 2689824
# 2   chromedriver                        0x0000000104cd23ec cxxbridge1$string$len + 90648
# 3   chromedriver                        0x0000000104d19544 cxxbridge1$string$len + 381808
# 4   chromedriver                        0x0000000104d5a934 cxxbridge1$string$len + 649056
# 5   chromedriver                        0x0000000104d0d834 cxxbridge1$string$len + 333408
# 6   chromedriver                        0x000000010514bfc0 cxxbridge1$str$ptr + 2473268
# 7   chromedriver                        0x000000010514f22c cxxbridge1$str$ptr + 2486176
# 8   chromedriver                        0x000000010512da08 cxxbridge1$str$ptr + 2348924
# 9   chromedriver                        0x000000010514fae8 cxxbridge1$str$ptr + 2488412
# 10  chromedriver                        0x000000010511ea98 cxxbridge1$str$ptr + 2287628
# 11  chromedriver                        0x000000010516f9d8 cxxbridge1$str$ptr + 2619212
# 12  chromedriver                        0x000000010516fb64 cxxbridge1$str$ptr + 2619608
# 13  chromedriver                        0x00000001051809e8 cxxbridge1$str$ptr + 2688860
# 14  libsystem_pthread.dylib             0x000000018209ec0c _pthread_start + 136
# 15  libsystem_pthread.dylib             0x0000000182099b80 thread_start + 8
#
# DevOps / 시스템 관리자 직무 선택!
# ['Linux', 'PostgreSQL', 'Docker', 'Kubernetes', 'VDI', 'Oracle', 'Active Directory', '보안', '보안 정책', '보안 관리']
# QA,테스트 엔지니어 직무 선택!
# ['JIRA', 'Slack', '테스트 케이스', 'QA 엔지니어링', 'iOS', 'Android', '테스트 계획', 'Confluence', 'SQL', 'JavaScript']
# 안드로이드 개발자 직무 선택!
# ['JavaScript', 'Git', 'React', 'TypeScript', 'HTML', 'CSS', 'Next.js', 'PHP', 'Laravel', 'React.js']
# iOS 개발자 직무 선택!
# ['JavaScript', 'Git', 'React', 'TypeScript', 'HTML', 'CSS', 'Next.js', 'PHP', 'Laravel', 'React.js']
# CTO,Chief Technology Officer 직무 선택!
# CTO,Chief Technology Officer에서 오류 발생 : Message:
# Stacktrace:
# 0   chromedriver                        0x0000000105188ea4 cxxbridge1$str$ptr + 2722840
# 1   chromedriver                        0x0000000105180dac cxxbridge1$str$ptr + 2689824
# 2   chromedriver                        0x0000000104cd23ec cxxbridge1$string$len + 90648
# 3   chromedriver                        0x0000000104d19544 cxxbridge1$string$len + 381808
# 4   chromedriver                        0x0000000104d5a934 cxxbridge1$string$len + 649056
# 5   chromedriver                        0x0000000104d0d834 cxxbridge1$string$len + 333408
# 6   chromedriver                        0x000000010514bfc0 cxxbridge1$str$ptr + 2473268
# 7   chromedriver                        0x000000010514f22c cxxbridge1$str$ptr + 2486176
# 8   chromedriver                        0x000000010512da08 cxxbridge1$str$ptr + 2348924
# 9   chromedriver                        0x000000010514fae8 cxxbridge1$str$ptr + 2488412
# 10  chromedriver                        0x000000010511ea98 cxxbridge1$str$ptr + 2287628
# 11  chromedriver                        0x000000010516f9d8 cxxbridge1$str$ptr + 2619212
# 12  chromedriver                        0x000000010516fb64 cxxbridge1$str$ptr + 2619608
# 13  chromedriver                        0x00000001051809e8 cxxbridge1$str$ptr + 2688860
# 14  libsystem_pthread.dylib             0x000000018209ec0c _pthread_start + 136
# 15  libsystem_pthread.dylib             0x0000000182099b80 thread_start + 8
#
# 서버 개발자 직무 선택!
# ['Java', 'Spring Boot', 'Python', 'AWS', 'Oracle', 'JavaScript', 'Git', 'MySQL', 'Docker', 'MongoDB']
# 웹 개발자 직무 선택!
# ['Java', 'JavaScript', 'HTML', 'CSS', 'Git', 'Oracle', 'Spring Framework', 'Spring Boot', 'TypeScript', 'React']
# 프로덕트 매니저 직무 선택!
# 프로덕트 매니저에서 오류 발생 : Message:
# Stacktrace:
# 0   chromedriver                        0x0000000105188ea4 cxxbridge1$str$ptr + 2722840
# 1   chromedriver                        0x0000000105180dac cxxbridge1$str$ptr + 2689824
# 2   chromedriver                        0x0000000104cd23ec cxxbridge1$string$len + 90648
# 3   chromedriver                        0x0000000104d19544 cxxbridge1$string$len + 381808
# 4   chromedriver                        0x0000000104d5a934 cxxbridge1$string$len + 649056
# 5   chromedriver                        0x0000000104d0d834 cxxbridge1$string$len + 333408
# 6   chromedriver                        0x000000010514bfc0 cxxbridge1$str$ptr + 2473268
# 7   chromedriver                        0x000000010514f22c cxxbridge1$str$ptr + 2486176
# 8   chromedriver                        0x000000010512da08 cxxbridge1$str$ptr + 2348924
# 9   chromedriver                        0x000000010514fae8 cxxbridge1$str$ptr + 2488412
# 10  chromedriver                        0x000000010511ea98 cxxbridge1$str$ptr + 2287628
# 11  chromedriver                        0x000000010516f9d8 cxxbridge1$str$ptr + 2619212
# 12  chromedriver                        0x000000010516fb64 cxxbridge1$str$ptr + 2619608
# 13  chromedriver                        0x00000001051809e8 cxxbridge1$str$ptr + 2688860
# 14  libsystem_pthread.dylib             0x000000018209ec0c _pthread_start + 136
# 15  libsystem_pthread.dylib             0x0000000182099b80 thread_start + 8
#
# 개발 매니저 직무 선택!
# ['Git', 'Oracle', 'CSS', 'HTML', 'Java', 'JavaScript', 'SQL', 'Spring Framework']
# Node.js 개발자 직무 선택!
# Node.js 개발자에서 오류 발생 : Message:
# Stacktrace:
# 0   chromedriver                        0x0000000105188ea4 cxxbridge1$str$ptr + 2722840
# 1   chromedriver                        0x0000000105180dac cxxbridge1$str$ptr + 2689824
# 2   chromedriver                        0x0000000104cd23ec cxxbridge1$string$len + 90648
# 3   chromedriver                        0x0000000104d19544 cxxbridge1$string$len + 381808
# 4   chromedriver                        0x0000000104d5a934 cxxbridge1$string$len + 649056
# 5   chromedriver                        0x0000000104d0d834 cxxbridge1$string$len + 333408
# 6   chromedriver                        0x000000010514bfc0 cxxbridge1$str$ptr + 2473268
# 7   chromedriver                        0x000000010514f22c cxxbridge1$str$ptr + 2486176
# 8   chromedriver                        0x000000010512da08 cxxbridge1$str$ptr + 2348924
# 9   chromedriver                        0x000000010514fae8 cxxbridge1$str$ptr + 2488412
# 10  chromedriver                        0x000000010511ea98 cxxbridge1$str$ptr + 2287628
# 11  chromedriver                        0x000000010516f9d8 cxxbridge1$str$ptr + 2619212
# 12  chromedriver                        0x000000010516fb64 cxxbridge1$str$ptr + 2619608
# 13  chromedriver                        0x00000001051809e8 cxxbridge1$str$ptr + 2688860
# 14  libsystem_pthread.dylib             0x000000018209ec0c _pthread_start + 136
# 15  libsystem_pthread.dylib             0x0000000182099b80 thread_start + 8
#
# 영상,음성 엔지니어 직무 선택!
# 영상,음성 엔지니어에서 오류 발생 : Message:
# Stacktrace:
# 0   chromedriver                        0x0000000105188ea4 cxxbridge1$str$ptr + 2722840
# 1   chromedriver                        0x0000000105180dac cxxbridge1$str$ptr + 2689824
# 2   chromedriver                        0x0000000104cd23ec cxxbridge1$string$len + 90648
# 3   chromedriver                        0x0000000104d19544 cxxbridge1$string$len + 381808
# 4   chromedriver                        0x0000000104d5a934 cxxbridge1$string$len + 649056
# 5   chromedriver                        0x0000000104d0d834 cxxbridge1$string$len + 333408
# 6   chromedriver                        0x000000010514bfc0 cxxbridge1$str$ptr + 2473268
# 7   chromedriver                        0x000000010514f22c cxxbridge1$str$ptr + 2486176
# 8   chromedriver                        0x000000010512da08 cxxbridge1$str$ptr + 2348924
# 9   chromedriver                        0x000000010514fae8 cxxbridge1$str$ptr + 2488412
# 10  chromedriver                        0x000000010511ea98 cxxbridge1$str$ptr + 2287628
# 11  chromedriver                        0x000000010516f9d8 cxxbridge1$str$ptr + 2619212
# 12  chromedriver                        0x000000010516fb64 cxxbridge1$str$ptr + 2619608
# 13  chromedriver                        0x00000001051809e8 cxxbridge1$str$ptr + 2688860
# 14  libsystem_pthread.dylib             0x000000018209ec0c _pthread_start + 136
# 15  libsystem_pthread.dylib             0x0000000182099b80 thread_start + 8
#
# 파이썬 개발자 직무 선택!
# 파이썬 개발자에서 오류 발생 : Message:
# Stacktrace:
# 0   chromedriver                        0x0000000105188ea4 cxxbridge1$str$ptr + 2722840
# 1   chromedriver                        0x0000000105180dac cxxbridge1$str$ptr + 2689824
# 2   chromedriver                        0x0000000104cd23ec cxxbridge1$string$len + 90648
# 3   chromedriver                        0x0000000104d19544 cxxbridge1$string$len + 381808
# 4   chromedriver                        0x0000000104d5a934 cxxbridge1$string$len + 649056
# 5   chromedriver                        0x0000000104d0d834 cxxbridge1$string$len + 333408
# 6   chromedriver                        0x000000010514bfc0 cxxbridge1$str$ptr + 2473268
# 7   chromedriver                        0x000000010514f22c cxxbridge1$str$ptr + 2486176
# 8   chromedriver                        0x000000010512da08 cxxbridge1$str$ptr + 2348924
# 9   chromedriver                        0x000000010514fae8 cxxbridge1$str$ptr + 2488412
# 10  chromedriver                        0x000000010511ea98 cxxbridge1$str$ptr + 2287628
# 11  chromedriver                        0x000000010516f9d8 cxxbridge1$str$ptr + 2619212
# 12  chromedriver                        0x000000010516fb64 cxxbridge1$str$ptr + 2619608
# 13  chromedriver                        0x00000001051809e8 cxxbridge1$str$ptr + 2688860
# 14  libsystem_pthread.dylib             0x000000018209ec0c _pthread_start + 136
# 15  libsystem_pthread.dylib             0x0000000182099b80 thread_start + 8
#
# C,C++ 개발자 직무 선택!
# ['Git', 'Java', 'AWS', 'JavaScript', 'MySQL', 'Spring Framework', 'TypeScript', 'MongoDB']
# 웹 퍼블리셔 직무 선택!
# ['Git', 'Java', 'AWS', 'JavaScript', 'MySQL', 'Spring Framework', 'TypeScript', 'MongoDB']
# BI 엔지니어 직무 선택!
# BI 엔지니어에서 오류 발생 : Message:
# Stacktrace:
# 0   chromedriver                        0x0000000105188ea4 cxxbridge1$str$ptr + 2722840
# 1   chromedriver                        0x0000000105180dac cxxbridge1$str$ptr + 2689824
# 2   chromedriver                        0x0000000104cd23ec cxxbridge1$string$len + 90648
# 3   chromedriver                        0x0000000104d19544 cxxbridge1$string$len + 381808
# 4   chromedriver                        0x0000000104d5a934 cxxbridge1$string$len + 649056
# 5   chromedriver                        0x0000000104d0d834 cxxbridge1$string$len + 333408
# 6   chromedriver                        0x000000010514bfc0 cxxbridge1$str$ptr + 2473268
# 7   chromedriver                        0x000000010514f22c cxxbridge1$str$ptr + 2486176
# 8   chromedriver                        0x000000010512da08 cxxbridge1$str$ptr + 2348924
# 9   chromedriver                        0x000000010514fae8 cxxbridge1$str$ptr + 2488412
# 10  chromedriver                        0x000000010511ea98 cxxbridge1$str$ptr + 2287628
# 11  chromedriver                        0x000000010516f9d8 cxxbridge1$str$ptr + 2619212
# 12  chromedriver                        0x000000010516fb64 cxxbridge1$str$ptr + 2619608
# 13  chromedriver                        0x00000001051809e8 cxxbridge1$str$ptr + 2688860
# 14  libsystem_pthread.dylib             0x000000018209ec0c _pthread_start + 136
# 15  libsystem_pthread.dylib             0x0000000182099b80 thread_start + 8
#
# 데이터 사이언티스트 직무 선택!
# ['Python', 'SQL', 'Git', 'NLP', 'Linux', 'Docker', 'Tableau', 'ML', 'Scikit-Learn', 'GitHub']
# 빅데이터 엔지니어 직무 선택!
# 빅데이터 엔지니어에서 오류 발생 : Message:
# Stacktrace:
# 0   chromedriver                        0x0000000105188ea4 cxxbridge1$str$ptr + 2722840
# 1   chromedriver                        0x0000000105180dac cxxbridge1$str$ptr + 2689824
# 2   chromedriver                        0x0000000104cd23ec cxxbridge1$string$len + 90648
# 3   chromedriver                        0x0000000104d19544 cxxbridge1$string$len + 381808
# 4   chromedriver                        0x0000000104d5a934 cxxbridge1$string$len + 649056
# 5   chromedriver                        0x0000000104d0d834 cxxbridge1$string$len + 333408
# 6   chromedriver                        0x000000010514bfc0 cxxbridge1$str$ptr + 2473268
# 7   chromedriver                        0x000000010514f22c cxxbridge1$str$ptr + 2486176
# 8   chromedriver                        0x000000010512da08 cxxbridge1$str$ptr + 2348924
# 9   chromedriver                        0x000000010514fae8 cxxbridge1$str$ptr + 2488412
# 10  chromedriver                        0x000000010511ea98 cxxbridge1$str$ptr + 2287628
# 11  chromedriver                        0x000000010516f9d8 cxxbridge1$str$ptr + 2619212
# 12  chromedriver                        0x000000010516fb64 cxxbridge1$str$ptr + 2619608
# 13  chromedriver                        0x00000001051809e8 cxxbridge1$str$ptr + 2688860
# 14  libsystem_pthread.dylib             0x000000018209ec0c _pthread_start + 136
# 15  libsystem_pthread.dylib             0x0000000182099b80 thread_start + 8
#
# 기술지원 직무 선택!
# ['Linux', 'Kubernetes', 'VDI', 'PostgreSQL', 'Oracle', 'Active Directory', 'Docker']
# 블록체인 플랫폼 엔지니어 직무 선택!
# 블록체인 플랫폼 엔지니어에서 오류 발생 : Message:
# Stacktrace:
# 0   chromedriver                        0x0000000105188ea4 cxxbridge1$str$ptr + 2722840
# 1   chromedriver                        0x0000000105180dac cxxbridge1$str$ptr + 2689824
# 2   chromedriver                        0x0000000104cd23ec cxxbridge1$string$len + 90648
# 3   chromedriver                        0x0000000104d19544 cxxbridge1$string$len + 381808
# 4   chromedriver                        0x0000000104d5a934 cxxbridge1$string$len + 649056
# 5   chromedriver                        0x0000000104d0d834 cxxbridge1$string$len + 333408
# 6   chromedriver                        0x000000010514bfc0 cxxbridge1$str$ptr + 2473268
# 7   chromedriver                        0x000000010514f22c cxxbridge1$str$ptr + 2486176
# 8   chromedriver                        0x000000010512da08 cxxbridge1$str$ptr + 2348924
# 9   chromedriver                        0x000000010514fae8 cxxbridge1$str$ptr + 2488412
# 10  chromedriver                        0x000000010511ea98 cxxbridge1$str$ptr + 2287628
# 11  chromedriver                        0x000000010516f9d8 cxxbridge1$str$ptr + 2619212
# 12  chromedriver                        0x000000010516fb64 cxxbridge1$str$ptr + 2619608
# 13  chromedriver                        0x00000001051809e8 cxxbridge1$str$ptr + 2688860
# 14  libsystem_pthread.dylib             0x000000018209ec0c _pthread_start + 136
# 15  libsystem_pthread.dylib             0x0000000182099b80 thread_start + 8
#
# 머신러닝 엔지니어 직무 선택!
# ['Kubernetes', 'Redis', 'MongoDB', 'AWS', 'JavaScript', 'FastAPI', 'Nest.js', 'Linux', 'ML', 'PostgreSQL']
# 소프트웨어 엔지니어 직무 선택!
# ['PostgreSQL', 'Oracle', 'Docker', 'GitHub', 'React', 'Java', 'Python', 'AWS', 'Node.js', 'Git']
# 크로스플랫폼 앱 개발자 직무 선택!
# 크로스플랫폼 앱 개발자에서 오류 발생 : Message:
# Stacktrace:
# 0   chromedriver                        0x0000000105188ea4 cxxbridge1$str$ptr + 2722840
# 1   chromedriver                        0x0000000105180dac cxxbridge1$str$ptr + 2689824
# 2   chromedriver                        0x0000000104cd23ec cxxbridge1$string$len + 90648
# 3   chromedriver                        0x0000000104d19544 cxxbridge1$string$len + 381808
# 4   chromedriver                        0x0000000104d5a934 cxxbridge1$string$len + 649056
# 5   chromedriver                        0x0000000104d0d834 cxxbridge1$string$len + 333408
# 6   chromedriver                        0x000000010514bfc0 cxxbridge1$str$ptr + 2473268
# 7   chromedriver                        0x000000010514f22c cxxbridge1$str$ptr + 2486176
# 8   chromedriver                        0x000000010512da08 cxxbridge1$str$ptr + 2348924
# 9   chromedriver                        0x000000010514fae8 cxxbridge1$str$ptr + 2488412
# 10  chromedriver                        0x000000010511ea98 cxxbridge1$str$ptr + 2287628
# 11  chromedriver                        0x000000010516f9d8 cxxbridge1$str$ptr + 2619212
# 12  chromedriver                        0x000000010516fb64 cxxbridge1$str$ptr + 2619608
# 13  chromedriver                        0x00000001051809e8 cxxbridge1$str$ptr + 2688860
# 14  libsystem_pthread.dylib             0x000000018209ec0c _pthread_start + 136
# 15  libsystem_pthread.dylib             0x0000000182099b80 thread_start + 8
#
# DBA 직무 선택!
# DBA에서 오류 발생 : Message:
# Stacktrace:
# 0   chromedriver                        0x0000000105188ea4 cxxbridge1$str$ptr + 2722840
# 1   chromedriver                        0x0000000105180dac cxxbridge1$str$ptr + 2689824
# 2   chromedriver                        0x0000000104cd23ec cxxbridge1$string$len + 90648
# 3   chromedriver                        0x0000000104d19544 cxxbridge1$string$len + 381808
# 4   chromedriver                        0x0000000104d5a934 cxxbridge1$string$len + 649056
# 5   chromedriver                        0x0000000104d0d834 cxxbridge1$string$len + 333408
# 6   chromedriver                        0x000000010514bfc0 cxxbridge1$str$ptr + 2473268
# 7   chromedriver                        0x000000010514f22c cxxbridge1$str$ptr + 2486176
# 8   chromedriver                        0x000000010512da08 cxxbridge1$str$ptr + 2348924
# 9   chromedriver                        0x000000010514fae8 cxxbridge1$str$ptr + 2488412
# 10  chromedriver                        0x000000010511ea98 cxxbridge1$str$ptr + 2287628
# 11  chromedriver                        0x000000010516f9d8 cxxbridge1$str$ptr + 2619212
# 12  chromedriver                        0x000000010516fb64 cxxbridge1$str$ptr + 2619608
# 13  chromedriver                        0x00000001051809e8 cxxbridge1$str$ptr + 2688860
# 14  libsystem_pthread.dylib             0x000000018209ec0c _pthread_start + 136
# 15  libsystem_pthread.dylib             0x0000000182099b80 thread_start + 8
#
# CSV 저장 완료!
